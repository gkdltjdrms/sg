# %%
from tensorflow.keras.datasets import cifar10, cifar100
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Dropout, MaxPooling2D
import datetime 
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
#1. 데이터
(x_train, y_train), (X_test, y_test) = cifar10.load_data()

# # print(x_train.shape, y_train.shape) # (50000, 32, 32, 3) (50000, 1)
# print(X_test.shape, y_test.shape) # (10000, 32, 32, 3) (10000,)
# print(x_train.shape, y_train.shape)  
# print(X_test.shape, y_test.shape)   

# print(np.unique(y_train, return_counts=True))

date = datetime.datetime.now()
date = date.strftime("%m%d_%H%M")
filepath = './_save/MCP/'
filename = '{epoch:04d}-{val_loss:.4f}.hdf5'  # 0037-0.0048.hdf5
path = './_save/'

#2. 모델 구성
model = Sequential()
model.add(Conv2D(filters= 128,kernel_size=(2,2), input_shape=(32,32,3),
                 padding='same',
                 activation='relu'))                       # (31, 31, 128)
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

#3. 컴파일, 훈련

# mode= auto, min, max 
es = EarlyStopping(monitor='acc',
                              mode='auto', 
                              patience=250,
                              restore_best_weights=True,
                              verbose=1)

mcp = ModelCheckpoint(monitor='val_loss', mode='auto', verbose=1,
                      save_best_only=True,
                      filepath=filepath + 'k30_' + date+'_' + filename)


model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', 
              metrics=['acc'])
model.fit(x_train, y_train, epochs=350, verbose=1, batch_size=2048,
          validation_split=0.3,
          callbacks=[es, mcp])

model.save(path + 'keras34_10_ModelCheckPointcifar_save_model.h5')
#4. 평가, 예측
results = model.evaluate(X_test, y_test)
print('loss :', results[0])
print('acc :', results[1])

## padding,maxpool acc:
# Out:
# Epoch 1/350
# 18/18 [==============================] - ETA: 0s - loss: 4.0419 - acc: 0.1133
# Epoch 00001: val_loss improved from inf to 2.25294, saving model to ./_save/MCP\k30_0125_1313_0001-2.2529.hdf5
# 18/18 [==============================] - 6s 147ms/step - loss: 4.0419 - acc: 0.1133 - val_loss: 2.2529 - val_acc: 0.1373
# Epoch 2/350
# 17/18 [===========================>..] - ETA: 0s - loss: 2.2480 - acc: 0.1449
# Epoch 00002: val_loss improved from 2.25294 to 2.15222, saving model to ./_save/MCP\k30_0125_1313_0002-2.1522.hdf5
# 18/18 [==============================] - 2s 102ms/step - loss: 2.2474 - acc: 0.1451 - val_loss: 2.1522 - val_acc: 0.1972
# Epoch 3/350
# 17/18 [===========================>..] - ETA: 0s - loss: 2.1810 - acc: 0.1888
# Epoch 00003: val_loss improved from 2.15222 to 2.06633, saving model to ./_save/MCP\k30_0125_1313_0003-2.0663.hdf5
# 18/18 [==============================] - 2s 102ms/step - loss: 2.1808 - acc: 0.1888 - val_loss: 2.0663 - val_acc: 0.2304
# Epoch 4/350
# 17/18 [===========================>..] - ETA: 0s - loss: 2.1179 - acc: 0.2140
# Epoch 00004: val_loss improved from 2.06633 to 2.00533, saving model to ./_save/MCP\k30_0125_1313_0004-2.0053.hdf5
# 18/18 [==============================] - 2s 102ms/step - loss: 2.1176 - acc: 0.2138 - val_loss: 2.0053 - val_acc: 0.2888
# Epoch 5/350
# 17/18 [===========================>..] - ETA: 0s - loss: 2.0227 - acc: 0.2498
# Epoch 00005: val_loss improved from 2.00533 to 1.88779, saving model to ./_save/MCP\k30_0125_1313_0005-1.8878.hdf5
# 18/18 [==============================] - 2s 103ms/step - loss: 2.0227 - acc: 0.2498 - val_loss: 1.8878 - val_acc: 0.3001
# Epoch 6/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.9533 - acc: 0.2757
# Epoch 00006: val_loss improved from 1.88779 to 1.81096, saving model to ./_save/MCP\k30_0125_1313_0006-1.8110.hdf5
# 18/18 [==============================] - 2s 103ms/step - loss: 1.9528 - acc: 0.2759 - val_loss: 1.8110 - val_acc: 0.3573
# Epoch 7/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.8733 - acc: 0.3114
# Epoch 00007: val_loss improved from 1.81096 to 1.69832, saving model to ./_save/MCP\k30_0125_1313_0007-1.6983.hdf5
# 18/18 [==============================] - 2s 103ms/step - loss: 1.8726 - acc: 0.3117 - val_loss: 1.6983 - val_acc: 0.3843
# Epoch 8/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.8098 - acc: 0.3420
# Epoch 00008: val_loss improved from 1.69832 to 1.64679, saving model to ./_save/MCP\k30_0125_1313_0008-1.6468.hdf5
# 18/18 [==============================] - 2s 103ms/step - loss: 1.8099 - acc: 0.3421 - val_loss: 1.6468 - val_acc: 0.4343
# Epoch 9/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.7996 - acc: 0.3569
# Epoch 00009: val_loss improved from 1.64679 to 1.61522, saving model to ./_save/MCP\k30_0125_1313_0009-1.6152.hdf5
# 18/18 [==============================] - 2s 103ms/step - loss: 1.7992 - acc: 0.3572 - val_loss: 1.6152 - val_acc: 0.4463
# Epoch 10/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.7348 - acc: 0.3828
# Epoch 00010: val_loss improved from 1.61522 to 1.56763, saving model to ./_save/MCP\k30_0125_1313_0010-1.5676.hdf5
# 18/18 [==============================] - 2s 103ms/step - loss: 1.7338 - acc: 0.3831 - val_loss: 1.5676 - val_acc: 0.4633
# Epoch 11/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.6538 - acc: 0.4123
# Epoch 00011: val_loss did not improve from 1.56763
# 18/18 [==============================] - 2s 101ms/step - loss: 1.6529 - acc: 0.4127 - val_loss: 1.5708 - val_acc: 0.4586
# Epoch 12/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.6580 - acc: 0.4104
# Epoch 00012: val_loss improved from 1.56763 to 1.49524, saving model to ./_save/MCP\k30_0125_1313_0012-1.4952.hdf5
# 18/18 [==============================] - 2s 103ms/step - loss: 1.6574 - acc: 0.4109 - val_loss: 1.4952 - val_acc: 0.4790
# Epoch 13/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.5906 - acc: 0.4368
# Epoch 00013: val_loss did not improve from 1.49524
# 18/18 [==============================] - 2s 101ms/step - loss: 1.5908 - acc: 0.4370 - val_loss: 1.5794 - val_acc: 0.4479
# Epoch 14/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.5943 - acc: 0.4397
# Epoch 00014: val_loss improved from 1.49524 to 1.45675, saving model to ./_save/MCP\k30_0125_1313_0014-1.4567.hdf5
# 18/18 [==============================] - 2s 103ms/step - loss: 1.5938 - acc: 0.4397 - val_loss: 1.4567 - val_acc: 0.4980
# Epoch 15/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.5190 - acc: 0.4651
# Epoch 00015: val_loss did not improve from 1.45675
# 18/18 [==============================] - 2s 101ms/step - loss: 1.5193 - acc: 0.4651 - val_loss: 1.5133 - val_acc: 0.4839
# Epoch 16/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.4955 - acc: 0.4805
# Epoch 00016: val_loss improved from 1.45675 to 1.38769, saving model to ./_save/MCP\k30_0125_1313_0016-1.3877.hdf5
# 18/18 [==============================] - 2s 104ms/step - loss: 1.4954 - acc: 0.4806 - val_loss: 1.3877 - val_acc: 0.5211
# Epoch 17/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.3976 - acc: 0.5111
# Epoch 00017: val_loss did not improve from 1.38769
# 18/18 [==============================] - 2s 101ms/step - loss: 1.3975 - acc: 0.5113 - val_loss: 1.4137 - val_acc: 0.5274
# Epoch 18/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.3771 - acc: 0.5185
# Epoch 00018: val_loss improved from 1.38769 to 1.34270, saving model to ./_save/MCP\k30_0125_1313_0018-1.3427.hdf5
# 18/18 [==============================] - 2s 104ms/step - loss: 1.3770 - acc: 0.5184 - val_loss: 1.3427 - val_acc: 0.5429
# Epoch 19/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.3222 - acc: 0.5387
# Epoch 00019: val_loss did not improve from 1.34270
# 18/18 [==============================] - 2s 101ms/step - loss: 1.3217 - acc: 0.5390 - val_loss: 1.3648 - val_acc: 0.5354
# Epoch 20/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.3073 - acc: 0.5450
# Epoch 00020: val_loss improved from 1.34270 to 1.33903, saving model to ./_save/MCP\k30_0125_1313_0020-1.3390.hdf5
# 18/18 [==============================] - 2s 104ms/step - loss: 1.3082 - acc: 0.5448 - val_loss: 1.3390 - val_acc: 0.5503
# Epoch 21/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.2668 - acc: 0.5626
# Epoch 00021: val_loss improved from 1.33903 to 1.32603, saving model to ./_save/MCP\k30_0125_1313_0021-1.3260.hdf5
# 18/18 [==============================] - 2s 104ms/step - loss: 1.2667 - acc: 0.5625 - val_loss: 1.3260 - val_acc: 0.5523
# Epoch 22/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.2218 - acc: 0.5753
# Epoch 00022: val_loss did not improve from 1.32603
# 18/18 [==============================] - 2s 102ms/step - loss: 1.2220 - acc: 0.5752 - val_loss: 1.3570 - val_acc: 0.5554
# Epoch 23/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.1826 - acc: 0.5901
# Epoch 00023: val_loss improved from 1.32603 to 1.32022, saving model to ./_save/MCP\k30_0125_1313_0023-1.3202.hdf5
# 18/18 [==============================] - 2s 104ms/step - loss: 1.1824 - acc: 0.5901 - val_loss: 1.3202 - val_acc: 0.5622
# Epoch 24/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.1508 - acc: 0.5989
# Epoch 00024: val_loss did not improve from 1.32022
# 18/18 [==============================] - 2s 102ms/step - loss: 1.1510 - acc: 0.5989 - val_loss: 1.3316 - val_acc: 0.5590
# Epoch 25/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.1303 - acc: 0.6105
# Epoch 00025: val_loss did not improve from 1.32022
# 18/18 [==============================] - 2s 102ms/step - loss: 1.1301 - acc: 0.6105 - val_loss: 1.3210 - val_acc: 0.5683
# Epoch 26/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.0980 - acc: 0.6193
# Epoch 00026: val_loss improved from 1.32022 to 1.30738, saving model to ./_save/MCP\k30_0125_1313_0026-1.3074.hdf5
# 18/18 [==============================] - 2s 104ms/step - loss: 1.0977 - acc: 0.6195 - val_loss: 1.3074 - val_acc: 0.5648
# Epoch 27/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.0756 - acc: 0.6293
# Epoch 00027: val_loss did not improve from 1.30738
# 18/18 [==============================] - 2s 102ms/step - loss: 1.0758 - acc: 0.6293 - val_loss: 1.3398 - val_acc: 0.5697
# Epoch 28/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.0290 - acc: 0.6427
# Epoch 00028: val_loss improved from 1.30738 to 1.29924, saving model to ./_save/MCP\k30_0125_1313_0028-1.2992.hdf5
# 18/18 [==============================] - 2s 105ms/step - loss: 1.0289 - acc: 0.6428 - val_loss: 1.2992 - val_acc: 0.5806
# Epoch 29/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.9969 - acc: 0.6560
# Epoch 00029: val_loss did not improve from 1.29924
# 18/18 [==============================] - 2s 102ms/step - loss: 0.9967 - acc: 0.6561 - val_loss: 1.3092 - val_acc: 0.5786
# Epoch 30/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.9739 - acc: 0.6656
# Epoch 00030: val_loss did not improve from 1.29924
# 18/18 [==============================] - 2s 103ms/step - loss: 0.9735 - acc: 0.6657 - val_loss: 1.3244 - val_acc: 0.5843
# Epoch 31/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.9423 - acc: 0.6784
# Epoch 00031: val_loss did not improve from 1.29924
# 18/18 [==============================] - 2s 102ms/step - loss: 0.9417 - acc: 0.6786 - val_loss: 1.4151 - val_acc: 0.5735
# Epoch 32/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.9316 - acc: 0.6810
# Epoch 00032: val_loss did not improve from 1.29924
# 18/18 [==============================] - 2s 103ms/step - loss: 0.9317 - acc: 0.6810 - val_loss: 1.5765 - val_acc: 0.5441
# Epoch 33/350
# 17/18 [===========================>..] - ETA: 0s - loss: 1.0858 - acc: 0.6323
# Epoch 00033: val_loss did not improve from 1.29924
# 18/18 [==============================] - 2s 102ms/step - loss: 1.0857 - acc: 0.6324 - val_loss: 1.4162 - val_acc: 0.5614
# Epoch 34/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.9444 - acc: 0.6779
# Epoch 00034: val_loss did not improve from 1.29924
# 18/18 [==============================] - 2s 102ms/step - loss: 0.9441 - acc: 0.6781 - val_loss: 1.3813 - val_acc: 0.5771
# Epoch 35/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.8773 - acc: 0.6982
# Epoch 00035: val_loss did not improve from 1.29924
# 18/18 [==============================] - 2s 103ms/step - loss: 0.8774 - acc: 0.6981 - val_loss: 1.3987 - val_acc: 0.5826
# Epoch 36/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.8384 - acc: 0.7129
# Epoch 00036: val_loss did not improve from 1.29924
# 18/18 [==============================] - 2s 103ms/step - loss: 0.8383 - acc: 0.7131 - val_loss: 1.3999 - val_acc: 0.5853
# Epoch 37/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.8177 - acc: 0.7234
# Epoch 00037: val_loss did not improve from 1.29924
# 18/18 [==============================] - 2s 103ms/step - loss: 0.8175 - acc: 0.7233 - val_loss: 1.4065 - val_acc: 0.5833
# Epoch 38/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.7877 - acc: 0.7335
# Epoch 00038: val_loss did not improve from 1.29924
# 18/18 [==============================] - 2s 103ms/step - loss: 0.7875 - acc: 0.7337 - val_loss: 1.4847 - val_acc: 0.5911
# Epoch 39/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.7743 - acc: 0.7369
# Epoch 00039: val_loss did not improve from 1.29924
# 18/18 [==============================] - 2s 103ms/step - loss: 0.7749 - acc: 0.7367 - val_loss: 1.4148 - val_acc: 0.5850
# Epoch 40/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.7591 - acc: 0.7430
# Epoch 00040: val_loss did not improve from 1.29924
# 18/18 [==============================] - 2s 104ms/step - loss: 0.7591 - acc: 0.7429 - val_loss: 1.5206 - val_acc: 0.5841
# Epoch 41/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.7621 - acc: 0.7458
# Epoch 00041: val_loss did not improve from 1.29924
# 18/18 [==============================] - 2s 103ms/step - loss: 0.7623 - acc: 0.7456 - val_loss: 1.6068 - val_acc: 0.5833
# Epoch 42/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.7283 - acc: 0.7528
# Epoch 00042: val_loss did not improve from 1.29924
# 18/18 [==============================] - 2s 105ms/step - loss: 0.7282 - acc: 0.7530 - val_loss: 1.5444 - val_acc: 0.5749
# Epoch 43/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.7415 - acc: 0.7536
# Epoch 00043: val_loss did not improve from 1.29924
# 18/18 [==============================] - 2s 105ms/step - loss: 0.7412 - acc: 0.7535 - val_loss: 1.4746 - val_acc: 0.5902
# Epoch 44/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.6978 - acc: 0.7648
# Epoch 00044: val_loss did not improve from 1.29924
# 18/18 [==============================] - 2s 104ms/step - loss: 0.6985 - acc: 0.7646 - val_loss: 1.5205 - val_acc: 0.5860
# Epoch 45/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.6810 - acc: 0.7722
# Epoch 00045: val_loss did not improve from 1.29924
# 18/18 [==============================] - 6s 337ms/step - loss: 0.6812 - acc: 0.7721 - val_loss: 1.5544 - val_acc: 0.5850
# Epoch 46/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.6638 - acc: 0.7767
# Epoch 00046: val_loss did not improve from 1.29924
# 18/18 [==============================] - 7s 403ms/step - loss: 0.6638 - acc: 0.7765 - val_loss: 1.5620 - val_acc: 0.5873
# Epoch 47/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.6570 - acc: 0.7819
# Epoch 00047: val_loss did not improve from 1.29924
# 18/18 [==============================] - 7s 400ms/step - loss: 0.6569 - acc: 0.7820 - val_loss: 1.7139 - val_acc: 0.5789
# Epoch 48/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.6454 - acc: 0.7858
# Epoch 00048: val_loss did not improve from 1.29924
# 18/18 [==============================] - 4s 255ms/step - loss: 0.6460 - acc: 0.7857 - val_loss: 1.5751 - val_acc: 0.5861
# Epoch 49/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.6208 - acc: 0.7908
# Epoch 00049: val_loss did not improve from 1.29924
# 18/18 [==============================] - 7s 253ms/step - loss: 0.6209 - acc: 0.7908 - val_loss: 1.6783 - val_acc: 0.5917
# Epoch 50/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.5923 - acc: 0.8013
# Epoch 00050: val_loss did not improve from 1.29924
# 18/18 [==============================] - 7s 401ms/step - loss: 0.5920 - acc: 0.8013 - val_loss: 1.6111 - val_acc: 0.5945
# Epoch 51/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.5816 - acc: 0.8041
# Epoch 00051: val_loss did not improve from 1.29924
# 18/18 [==============================] - 7s 402ms/step - loss: 0.5825 - acc: 0.8040 - val_loss: 1.6458 - val_acc: 0.5873
# Epoch 52/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.5818 - acc: 0.8061
# Epoch 00052: val_loss did not improve from 1.29924
# 18/18 [==============================] - 6s 360ms/step - loss: 0.5811 - acc: 0.8063 - val_loss: 1.6415 - val_acc: 0.5987
# Epoch 53/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.5577 - acc: 0.8141
# Epoch 00053: val_loss did not improve from 1.29924
# 18/18 [==============================] - 2s 104ms/step - loss: 0.5572 - acc: 0.8143 - val_loss: 1.6852 - val_acc: 0.5915
# Epoch 54/350
# 17/18 [===========================>..] - ETA: 0s - loss: 0.5467 - acc: 0.8211
# Epoch 00054: val_loss did not improve from 1.29924
# 18/18 [==============================] - 2s 104ms/step - loss: 0.5469 - acc: 0.8210 - val_loss: 1.7463 - val_acc: 0.5915
# Epoch 55/350
#  3/18 [====>.........................] - ETA: 1s - loss: 0.5184 - acc: 0.8267
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9568\4128712226.py in <module>
#      53 model.compile(loss='sparse_categorical_crossentropy', optimizer='adam',
#      54               metrics=['acc'])
# ---> 55 model.fit(x_train, y_train, epochs=350, verbose=1, batch_size=2048,
#      56           validation_split=0.3,
#      57           callbacks=[es, mcp])
#
# c:\anaconda3\envs\tf274gpu\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\anaconda3\envs\tf274gpu\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1219               logs = tmp_logs  # No error, now safe to assign to logs.
#    1220               end_step = step + data_handler.step_increment
# -> 1221               callbacks.on_train_batch_end(end_step, logs)
#    1222               if self.stop_training:
#    1223                 break
#
# c:\anaconda3\envs\tf274gpu\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#     434     """
#     435     if self._should_call_train_batch_hooks:
# --> 436       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     437
#     438   def on_test_batch_begin(self, batch, logs=None):
#
# c:\anaconda3\envs\tf274gpu\lib\site-packages\keras\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError(
#
# c:\anaconda3\envs\tf274gpu\lib\site-packages\keras\callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     314       self._batch_times.append(batch_time)
#     315
# --> 316     self._call_batch_hook_helper(hook_name, batch, logs)
#     317
#     318     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# c:\anaconda3\envs\tf274gpu\lib\site-packages\keras\callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     352     for callback in self.callbacks:
#     353       hook = getattr(callback, hook_name)
# --> 354       hook(batch, logs)
#     355
#     356     if self._check_timing:
#
# c:\anaconda3\envs\tf274gpu\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#    1030
#    1031   def on_train_batch_end(self, batch, logs=None):
# -> 1032     self._batch_update_progbar(batch, logs)
#    1033
#    1034   def on_test_batch_end(self, batch, logs=None):
#
# c:\anaconda3\envs\tf274gpu\lib\site-packages\keras\callbacks.py in _batch_update_progbar(self, batch, logs)
#    1102     if self.verbose == 1:
#    1103       # Only block async when verbose = 1.
# -> 1104       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1105       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1106
#
# c:\anaconda3\envs\tf274gpu\lib\site-packages\keras\utils\tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#     553
# --> 554   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     555
#     556
#
# c:\anaconda3\envs\tf274gpu\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# c:\anaconda3\envs\tf274gpu\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# c:\anaconda3\envs\tf274gpu\lib\site-packages\keras\utils\tf_utils.py in _to_single_numpy_or_python_type(t)
#     548   def _to_single_numpy_or_python_type(t):
#     549     if isinstance(t, tf.Tensor):
# --> 550       x = t.numpy()
#     551       return x.item() if np.ndim(x) == 0 else x
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# c:\anaconda3\envs\tf274gpu\lib\site-packages\tensorflow\python\framework\ops.py in numpy(self)
#    1147     """
#    1148     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1149     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1150     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1151
#
# c:\anaconda3\envs\tf274gpu\lib\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#    1113   def _numpy(self):
#    1114     try:
# -> 1115       return self._numpy_internal()
#    1116     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1117       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:
